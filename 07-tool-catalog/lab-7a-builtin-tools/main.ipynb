# %% [markdown]
# # Built-in tools: RAG + Code Interpreter
#
#
# 1. **File Search (RAG)**: Search within an Apollo 14 document.
# 2. **Code Interpreter**: Calculate asteroid crater size.
#
# > ⚠️ **Important**: File search requires a **local model deployment** in the AI Foundry project.
# > Unlike other labs that can use only the APIM gateway, File search needs direct model access
# > for its internal processing. This lab deploys a local `gpt-4.1` model alongside the APIM connection.

# %% [markdown]
# ## Setup
# Initialize the client and ensure resources exist.

# %%
# Enable automatic masking of Azure resource names in print output
import sys
sys.path.insert(0, "../../")
from secure_print import install
install()
# Out:
# secure_print: Azure resource masking enabled

# %%
# !pip install azure-ai-projects==2.0.0b2 -q
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import subprocess

# Configuration
RESOURCE_GROUP = "lab7a-builtin-tools"
LOCATION = "swedencentral"

# Check if resource group exists
result = subprocess.run(
    f'az group exists -n {RESOURCE_GROUP}',
    shell=True, capture_output=True, text=True
)

if result.stdout.strip() == 'false':
    print(f"📦 Creating resource group: {RESOURCE_GROUP}")
    subprocess.run(f'az group create -n {RESOURCE_GROUP} -l {LOCATION}', shell=True, check=True)
else:
    print(f"📦 Resource group exists: {RESOURCE_GROUP}")

# Get deployer principal ID for RBAC
deployer_id = subprocess.run(
    'az ad signed-in-user show --query id -o tsv',
    shell=True, capture_output=True, text=True
).stdout.strip()

# %%
# %%bash -s "$RESOURCE_GROUP" "$deployer_id"
# # Deploy Infrastructure
# az deployment group create \
#     -g $1 \
#     -n spoke \
#     -f spoke.bicep \
#     -p deployerPrincipalId=$2 \
#     --query "properties.outputs" \
#     -o json

# %%
import subprocess, json, time, os
from azure.ai.projects import AIProjectClient
# Added CodeInterpreterToolAuto
from azure.ai.projects.models import PromptAgentDefinition, FileSearchTool, CodeInterpreterTool, CodeInterpreterToolAuto
from azure.identity import DefaultAzureCredential

# Get outputs
outputs = json.loads(subprocess.run(
    f'az deployment group show -g {RESOURCE_GROUP} -n spoke --query properties.outputs -o json',
    shell=True, capture_output=True, text=True
).stdout)

PROJECT_ENDPOINT = outputs['projectEndpoint']['value']
MODEL_DEPLOYMENT = outputs['modelDeploymentName']['value']

# Set environment variables for the SDK to use
os.environ["AZURE_AI_MODEL_DEPLOYMENT_NAME"] = MODEL_DEPLOYMENT
os.environ["FOUNDRY_PROJECT_ENDPOINT"] = PROJECT_ENDPOINT

project_client = AIProjectClient(
    endpoint=PROJECT_ENDPOINT, 
    credential=DefaultAzureCredential()
)

# Get the OpenAI-compatible client for agent operations
openai_client = project_client.get_openai_client()

print(f"✅ Connected to Project: {PROJECT_ENDPOINT}")
print(f"✅ Model Deployment: {MODEL_DEPLOYMENT}")
# Out:
# ✅ Connected to Project: https://ai-***.services.ai.azure.com/api/projects/builtin-tools-lab
# ✅ Model Deployment: gpt-4o-mini

# %% [markdown]
# ## 1. File Search (RAG)
# We'll download an Apollo 14 document and ask the agent about the "abort switch".

# %%
# Download Apollo 14 Flight Journal Index
import urllib.request
urllib.request.urlretrieve("https://apollojournals.org/afj/ap14fj/19_day5_troubleshooting_lm_computer.html", "apollo14.html")
print("✅ Downloaded apollo14.html")

# Create Vector Store
vector_store = openai_client.vector_stores.create(name="apollo-store")
print(f"✅ Vector Store: {vector_store.id}")

# Upload file to vector store (handles upload & poll)
with open("apollo14.html", "rb") as f:
    file = openai_client.vector_stores.files.upload_and_poll(
        vector_store_id=vector_store.id, 
        file=f
    )
print(f"✅ File Uploaded & Indexed: {file.id}")

# Create Agent with File Search Tool
with project_client:
    rag_agent = project_client.agents.create_version(
        agent_name="apollo-historian",
        definition=PromptAgentDefinition(
            model=MODEL_DEPLOYMENT,
            instructions="You are an Apollo expert. Use the file search tool to answer questions. Give exact citations.",
            tools=[FileSearchTool(vector_store_ids=[vector_store.id])],
        ),
        description="Apollo history expert"
    )

print(f"✅ Agent Created: {rag_agent.name} (v{rag_agent.version})")
# Out:
# ✅ Downloaded apollo14.html
# ✅ Vector Store: vs_WF8jUI4EMpP4mfs5nlobCwId
# ✅ File Uploaded & Indexed: assistant-MqGsYyf3AvRCQ1d6hddV1q
# ✅ Agent Created: apollo-historian (v1)

# %%
# Create Conversation
conversation = openai_client.conversations.create()
print(f"🧵 Conversation Created: {conversation.id}")

# Send Query
# Asking a specific technical question found in the transcript
question = "What verb and noun command did Houston ask Antares to enter to check the status of the abort bit?"
print(f"❓ Asking: '{question}'")

response = openai_client.responses.create(
    conversation=conversation.id,
    input=question,
    extra_body={
        "agent": {
            "name": rag_agent.name, 
            "version": rag_agent.version,
            "type": "agent_reference"
        }
    },
)

print(f"\n🤖 Answer:\n{response.output_text}")

# Cleanup
# project_client.agents.delete_version(rag_agent.name, rag_agent.version)
# Out:
# 🧵 Conversation Created: conv_9eac72d3db0f764a00yrqfXVf5kaU7s4dhFMigP9tiz44Rs31I
# ❓ Asking: 'What verb and noun command did Houston ask Antares to enter to check the status of the abort bit?'
#
# 🤖 Answer:
# Houston asked Antares to enter the command **Verb 21 Noun 01 Enter; 10 10 Enter; 107 Enter** in order to check the status of the abort bit.

# %% [markdown]
# ## 2. Crater Calculator (Code Interpreter)

# %%
project_client = AIProjectClient(
    endpoint=PROJECT_ENDPOINT, 
    credential=DefaultAzureCredential()
)

# Get the OpenAI-compatible client for agent operations
openai_client = project_client.get_openai_client()

# %%
from azure.ai.projects.models import CodeInterpreterToolAuto

INSTRUCTIONS = """
Calculate crater diameter (km) using Python.
Formula: D = 1.161 * (2700/2500)^0.33 * d^0.78 * v^0.44 * 9.81^(-0.22) * sin(45deg)^0.33 / 1000
where: d=diameter(m), v=velocity(m/s)

After executing the code with python,
return ONLY with the final number in km.
"""

# Create Agent with Code Interpreter
with project_client:
    code_agent = project_client.agents.create_version(
        agent_name="crater-calculator",
        definition=PromptAgentDefinition(
            model=MODEL_DEPLOYMENT,
            instructions=INSTRUCTIONS,
            tools=[CodeInterpreterTool(container=CodeInterpreterToolAuto(file_ids=[]))],
        ),
        description="Calculates crater sizes"
    )

print(f"✅ Agent Created: {code_agent.name} (v{code_agent.version})")
# Out:
# ✅ Agent Created: crater-calculator (v1)

# %%
import re
from IPython.display import display, HTML

query = "Asteroid size: 500m, Velocity: 20km/s"

# Create Conversation
conversation_calc = openai_client.conversations.create()
print(f"🧵 Conversation Created: {conversation_calc.id}")

print("❓ Sending query...")
response = openai_client.responses.create(
    conversation=conversation_calc.id,
    input=query,
    extra_body={
        "agent": {
            "name": code_agent.name, 
            "version": code_agent.version, 
            "type": "agent_reference"
        }
    },
)

response_text = response.output_text
print(f"\n🤖 Result: {response_text}")

# Display the generated Python code from Code Interpreter
print("\n" + "="*60)
print("📝 Generated Python Code:")
print("="*60)
for output_item in response.output:
    if output_item.type == "code_interpreter_call":
        # Display code with syntax highlighting
        code_html = f'''
<div style="background:#1e1e1e; padding:16px; border-radius:8px; margin:10px 0; border:1px solid #3c3c3c;">
<pre style="color:#d4d4d4; margin:0; white-space:pre-wrap; font-family:'Consolas','Monaco',monospace; font-size:13px;">{output_item.code}</pre>
</div>
'''
        display(HTML(code_html))
print("="*60)

# Visualize
try:
    if response_text:
        numbers = re.findall(r"\d+\.?\d*", response_text)
        crater_km = float(numbers[-1]) if numbers else None
        if crater_km:
            from crater_physics import validate_crater
            from crater_viz import visualize_crater
            
            val = validate_crater(crater_km, 500, 20)
            visualize_crater(crater_km, val)
        else:
            print("No number found in result.")
    else:
        print("No result text returned.")

except Exception as e:
    print(f"Could not visualize: {e}")
# Out:
# 🧵 Conversation Created: conv_e8db0fbc98b86adb00707Ksp6VZHFnzwZcOqrnBVHuaeDMPDs9
# ❓ Sending query...
#
# 🤖 Result: 6.39
#
# ============================================================
# 📝 Generated Python Code:
# ============================================================
# <div style="background:#1e1e1e; padding:16px; border-radius:8px; margin:10px 0; border:1px solid #3c3c3c;">
# <pre style="color:#d4d4d4; margin:0; white-space:pre-wrap; font-family:'Consolas','Monaco',monospace; font-size:13px;">import math
#
# # Given values
# d = 500  # diameter in meters
# v = 20 * 1000  # velocity in meters per second (20 km/s converted to m/s)
#
# # Constants
# rho1 = 2700  # density (kg/m^3)
# rho2 = 2500  # density (kg/m^3)
# g = 9.81  # acceleration due to gravity (m/s^2)
#
# # Formula for crater diameter
# D = 1.161 * (rho1 / rho2)**0.33 * d**0.78 * v**0.44 * g**(-0.22) * math.sin(math.radians(45))**0.33 / 1000  # in kilometers
#
# D</pre>
# </div>
# ============================================================
# <style>
#     @keyframes growBar_0086518a {
#         0% { width: 0; opacity: 0; }
#         100% { width: var(--target-width); opacity: 1; }
#     }
#     @keyframes fadeIn_0086518a {
#         0% { opacity: 0; transform: translateY(12px); }
#         100% { opacity: 1; transform: translateY(0); }
#     }
#     .crater-container-0086518a {
#         font-family: 'Poppins', -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif;
#         background: linear-gradient(145deg, #0A192F 0%, #112240 100%);
#         padding: 28px 32px;
#         border-radius: 16px;
#         border: 1px solid rgba(100, 255, 218, 0.1);
#         max-width: 480px;
#         animation: fadeIn_0086518a 0.6s ease-out;
#         box-shadow: 0 10px 40px -10px rgba(2, 12, 27, 0.7);
#     }
#     .crater-header-0086518a {
#         margin-bottom: 28px;
#         padding-bottom: 20px;
#         border-bottom: 1px solid rgba(100, 255, 218, 0.1);
#     }
#     .crater-title-0086518a {
#         margin: 0;
#         color: #CCD6F6;
#         font-size: 18px;
#         font-weight: 600;
#         letter-spacing: -0.01em;
#     }
#     .crater-subtitle-0086518a {
#         margin: 4px 0 0 0;
#         color: #64FFDA;
#         font-family: 'Fira Code', 'SF Mono', Monaco, monospace;
#         font-size: 12px;
#         font-weight: 400;
#         letter-spacing: 0.02em;
#     }
#     .bar-section-0086518a {
#         margin-bottom: 20px;
#         animation: fadeIn_0086518a 0.7s ease-out backwards;
#     }
#     .bar-section-0086518a:nth-child(2) { animation-delay: 0.15s; }
#     .bar-section-0086518a:nth-child(3) { animation-delay: 0.3s; }
#     .bar-label-0086518a {
#         color: #8892B0;
#         font-size: 13px;
#         font-weight: 500;
#         margin-bottom: 10px;
#         display: flex;
#         justify-content: space-between;
#         align-items: baseline;
#     }
#     .bar-label-name-0086518a {
#         display: flex;
#         align-items: center;
#         gap: 8px;
#     }
#     .bar-label-name-0086518a::before {
#         content: '→';
#         color: #64FFDA;
#         font-family: 'Fira Code', monospace;
#         font-size: 11px;
#     }
#     .bar-value-0086518a {
#         color: #CCD6F6;
#         font-weight: 600;
#         font-family: 'Fira Code', 'SF Mono', Monaco, monospace;
#         font-size: 14px;
#     }
#     .bar-track-0086518a {
#         background: rgba(100, 255, 218, 0.05);
#         border-radius: 8px;
#         height: 32px;
#         overflow: hidden;
#         position: relative;
#         border: 1px solid rgba(100, 255, 218, 0.08);
#     }
#     .bar-fill-agent-0086518a {
#         --target-width: 316.5399133302292px;
#         height: 100%;
#         background: linear-gradient(90deg, #f97316, #fb923c);
#         border-radius: 7px;
#         animation: growBar_0086518a 1s cubic-bezier(0.4, 0, 0.2, 1) 0.3s forwards;
#         width: 0;
#         box-shadow: 0 0 20px rgba(249, 115, 22, 0.3);
#     }
#     .bar-fill-expected-0086518a {
#         --target-width: 316.6666666666667px;
#         height: 100%;
#         background: linear-gradient(90deg, #64FFDA, #5eead4);
#         border-radius: 7px;
#         animation: growBar_0086518a 1s cubic-bezier(0.4, 0, 0.2, 1) 0.5s forwards;
#         width: 0;
#         box-shadow: 0 0 20px rgba(100, 255, 218, 0.3);
#     }
#     .legend-0086518a {
#         display: flex;
#         gap: 24px;
#         margin-top: 24px;
#         padding-top: 20px;
#         border-top: 1px solid rgba(100, 255, 218, 0.1);
#         animation: fadeIn_0086518a 0.7s ease-out 0.6s backwards;
#     }
#     .legend-item-0086518a {
#         display: flex;
#         align-items: center;
#         gap: 10px;
#         font-size: 12px;
#         color: #8892B0;
#         font-weight: 500;
#     }
#     .legend-dot-agent-0086518a {
#         width: 14px;
#         height: 14px;
#         background: linear-gradient(135deg, #f97316, #fb923c);
#         border-radius: 4px;
#         box-shadow: 0 2px 8px rgba(249, 115, 22, 0.3);
#     }
#     .legend-dot-expected-0086518a {
#         width: 14px;
#         height: 14px;
#         background: linear-gradient(135deg, #64FFDA, #5eead4);
#         border-radius: 4px;
#         box-shadow: 0 2px 8px rgba(100, 255, 218, 0.3);
#     }
#     .comparison-0086518a {
#         margin-top: 16px;
#         font-size: 13px;
#         color: #8892B0;
#         font-family: 'Fira Code', 'SF Mono', Monaco, monospace;
#         animation: fadeIn_0086518a 0.7s ease-out 0.8s backwards;
#         padding: 12px 16px;
#         background: rgba(100, 255, 218, 0.03);
#         border-radius: 8px;
#         border: 1px solid rgba(100, 255, 218, 0.06);
#     }
#     .comparison-0086518a strong {
#         color: #CCD6F6;
#     }
#     .result-badge-0086518a {
#         margin-top: 20px;
#         padding: 14px 20px;
#         border-radius: 8px;
#         font-size: 14px;
#         font-weight: 600;
#         display: flex;
#         align-items: center;
#         gap: 12px;
#         animation: fadeIn_0086518a 0.7s ease-out 1s backwards;
#         letter-spacing: 0.01em;
#     }
#     .result-valid-0086518a {
#         background: rgba(100, 255, 218, 0.1);
#         border: 1px solid rgba(100, 255, 218, 0.25);
#         color: #64FFDA;
#     }
#     .result-invalid-0086518a {
#         background: rgba(255, 107, 107, 0.1);
#         border: 1px solid rgba(255, 107, 107, 0.25);
#         color: #ff6b6b;
#     }
#     .result-icon-0086518a {
#         font-size: 18px;
#     }
# </style>
#
# <div class="crater-container-0086518a">
#     <div class="crater-header-0086518a">
#         <h3 class="crater-title-0086518a">Crater Impact Analysis</h3>
#         <p class="crater-subtitle-0086518a">diameter comparison</p>
#     </div>
#
#     <div class="bar-section-0086518a">
#         <div class="bar-label-0086518a">
#             <span class="bar-label-name-0086518a">Agent Result</span>
#             <span class="bar-value-0086518a">6.39 km</span>
#         </div>
#         <div class="bar-track-0086518a">
#             <div class="bar-fill-agent-0086518a"></div>
#         </div>
#     </div>
#
#     <div class="bar-section-0086518a">
#         <div class="bar-label-0086518a">
#             <span class="bar-label-name-0086518a">Expected (Physics)</span>
#             <span class="bar-value-0086518a">6.39 km</span>
#         </div>
#         <div class="bar-track-0086518a">
#             <div class="bar-fill-expected-0086518a"></div>
#         </div>
#     </div>
#
#     <div class="legend-0086518a">
#         <div class="legend-item-0086518a">
#             <div class="legend-dot-agent-0086518a"></div>
#             <span>AI Agent</span>
#         </div>
#         <div class="legend-item-0086518a">
#             <div class="legend-dot-expected-0086518a"></div>
#             <span>Physics Model</span>
#         </div>
#     </div>
#
#     <div class="comparison-0086518a">
#         Δ <strong>0.003 km</strong> · 0.0% underestimate
#     </div>
#
#     <div class="result-badge-0086518a result-valid-0086518a">
#         <span class="result-icon-0086518a">✓</span>
#         Verified — within 10% tolerance
#     </div>
# </div>
